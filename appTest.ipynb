# %%
from chispitapp import ChispitApp
from geneticcode import genetic_code
from collections import Counter
import matplotlib.pyplot as plt

# %%
chispis = ChispitApp()
chispis.process_files('./data/', genetic_code, 'levaduras_XD')
generated_codes:list[list[str]] = chispis.get_generated_codes_per_genome()
# Out:
# ...
# 100%|██████████| 3/3 [00:00<?, ?it/s]

# %%
plt.hist(dict(Counter(generated_codes[0])).values(), bins=50)
plt.yscale('log')
